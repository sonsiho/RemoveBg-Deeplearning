# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.8.1
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: C:\Users\SonSiHo\anaconda3\envs\py311\Lib\site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by:

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_input_path = './data/HinhChuKy.png'
img = Image.open(img_input_path);

plt.imshow(img)

plt.show()

# %%
import cv2

img_input_path = './data/HinhChuKy.png'
image = cv2.imread(img_input_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (3,3), 0)
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Bitwise-and and color background white
result = cv2.bitwise_and(image, image, mask=thresh)
result[thresh==0] = [255,255,255]

cv2.imshow('thresh', thresh)
cv2.imshow('result', result)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 13
#      10 result = cv2.bitwise_and(image, image, mask=thresh)
#      11 result[thresh==0] = [255,255,255]
# ---> 13 cv2.imshow('thresh', thresh)
#      14 cv2.imshow('result', result)
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
